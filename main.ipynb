# %%
Python
# 1. 터미널 대신 노트북 안에서 안전하게 라이브러리 설치하기
# !pip install yfinance pandas ta pytz python-dotenv
print("====================================")
print("🔥 퀀트 필수 라이브러리 설치 완료! 🔥")
print("====================================")
# Out:
# 커널을 시작하지 못했습니다.
#
# 커널 'venv (3.13.13) (Python 3.13.13)'을(를) 시작하지 못했습니다.
#
# 자세한 내용은 Jupyter <a href='command:jupyter.viewOutput'>로그</a>을 참조하세요. listen EFAULT: bad address in system call argument :::9003
